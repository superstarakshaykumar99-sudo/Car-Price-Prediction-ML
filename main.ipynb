# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from six.moves import urllib
import warnings
warnings.filterwarnings("ignore")

# %%
data_dir = "./data/"

os.makedirs(data_dir, exist_ok=True)
print("data directory created")

data_url = "https://raw.githubusercontent.com/mohitmahiyt/cardataset/refs/heads/main/cars_dataset.csv"

filename = os.path.basename(data_url)
print(filename)

filepath = os.path.join(data_dir, filename)
print(filepath)

urllib.request.urlretrieve(data_url, filepath)
# Out:
# data directory created
# cars_dataset.csv
# ./data/cars_dataset.csv
# ('./data/cars_dataset.csv', <http.client.HTTPMessage at 0x129d622b0>)

# %%
df = pd.read_csv('./data/cars_dataset.csv')
df
# Out:
#        car data set                  NaN        NaN.1        NaN.2 NaN.3  \
# 0               NaN                  NaN          NaN          NaN   NaN
# 1               NaN                  NaN          NaN          NaN   NaN
# 2               NaN                  NaN          NaN          NaN   NaN
# 3               NaN                  NaN          NaN          NaN   NaN
# 4               NaN                  NaN          NaN          NaN   NaN
# ...             ...                  ...          ...          ...   ...
# 15807       30016.0  Bentley Continental      Bentley  Continental    10
# 15808       30017.0    Rolls-Royce Ghost  Rolls-Royce        Ghost     4
# 15809       30018.0  Bentley Continental      Bentley  Continental     9
# 15810       30019.0    Ferrari GTC4Lusso      Ferrari    GTC4Lusso     2
# 15811       30020.0  Bentley Continental      Bentley  Continental     9
#
#        NaN.4       NaN.5   NaN.6      NaN.7 NaN.8 NaN.9 NaN.10 NaN.11  \
# 0        NaN         NaN     NaN        NaN   NaN   NaN    NaN    NaN
# 1        NaN         NaN     NaN        NaN   NaN   NaN    NaN    NaN
# 2        NaN         NaN     NaN        NaN   NaN   NaN    NaN    NaN
# 3        NaN         NaN     NaN        NaN   NaN   NaN    NaN    NaN
# 4        NaN         NaN     NaN        NaN   NaN   NaN    NaN    NaN
# ...      ...         ...     ...        ...   ...   ...    ...    ...
# 15807  30000      Dealer  Petrol  Automatic   8.6  5998    552      4
# 15808   5000  Individual  Petrol  Automatic  10.2  6592    563      4
# 15809  37500      Dealer  Petrol  Automatic     6  5998    600      5
# 15810   3800      Dealer  Petrol  Automatic     4  3855    601      4
# 15811   9000      Dealer  Petrol  Automatic   9.5  5998    626      4
#
#          NaN.12 Unnamed: 14
# 0           NaN         NaN
# 1           NaN         NaN
# 2           NaN         NaN
# 3           NaN         NaN
# 4           NaN         NaN
# ...         ...         ...
# 15807   8100000         NaN
# 15808  24200000         NaN
# 15809   5200000         NaN
# 15810  39500000         NaN
# 15811  14500000         NaN
#
# [15812 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15812 entries, 0 to 15811
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   car data set  15411 non-null  float64
#  1   NaN           15412 non-null  object
#  2   NaN.1         15412 non-null  object
#  3   NaN.2         15412 non-null  object
#  4   NaN.3         15412 non-null  object
#  5   NaN.4         15412 non-null  object
#  6   NaN.5         15412 non-null  object
#  7   NaN.6         15412 non-null  object
#  8   NaN.7         15412 non-null  object
#  9   NaN.8         15412 non-null  object
#  10  NaN.9         15412 non-null  object
#  11  NaN.10        15412 non-null  object
#  12  NaN.11        15412 non-null  object
#  13  NaN.12        15412 non-null  object
#  14  Unnamed: 14   1 non-null      object
# dtypes: float64(1), object(14)
# memory usage: 1.8+ MB

# %%
df.head(40)
# Out:
#     car data set          NaN   NaN.1  NaN.2        NaN.3      NaN.4  \
# 0            NaN          NaN     NaN    NaN          NaN        NaN
# 1            NaN          NaN     NaN    NaN          NaN        NaN
# 2            NaN          NaN     NaN    NaN          NaN        NaN
# 3            NaN          NaN     NaN    NaN          NaN        NaN
# 4            NaN          NaN     NaN    NaN          NaN        NaN
# 5            NaN          NaN     NaN    NaN          NaN        NaN
# 6            NaN          NaN     NaN    NaN          NaN        NaN
# 7            NaN          NaN     NaN    NaN          NaN        NaN
# 8            NaN          NaN     NaN    NaN          NaN        NaN
# 9            NaN          NaN     NaN    NaN          NaN        NaN
# 10           NaN     car_name   brand  model  vehicle_age  km_driven
# 11           1.0  Maruti Alto  Maruti   Alto            9      53800
# 12           2.0  Maruti Alto  Maruti   Alto           11      11000
# 13           3.0  Maruti Alto  Maruti   Alto           11      80000
# 14           NaN          NaN     NaN    NaN          NaN        NaN
# 15           NaN          NaN     NaN    NaN          NaN        NaN
# 16           NaN          NaN     NaN    NaN          NaN        NaN
# 17           NaN          NaN     NaN    NaN          NaN        NaN
# 18           4.0  Maruti Alto  Maruti   Alto           10      57000
# 19           5.0  Maruti Alto  Maruti   Alto           11      72000
# 20           NaN          NaN     NaN    NaN          NaN        NaN
# 21           NaN          NaN     NaN    NaN          NaN        NaN
# 22           NaN          NaN     NaN    NaN          NaN        NaN
# 23           NaN          NaN     NaN    NaN          NaN        NaN
# 24           6.0  Maruti Alto  Maruti   Alto            5      42000
# 25           7.0  Maruti Alto  Maruti   Alto            7      28000
# 26           NaN          NaN     NaN    NaN          NaN        NaN
# 27           NaN          NaN     NaN    NaN          NaN        NaN
# 28           NaN          NaN     NaN    NaN          NaN        NaN
# 29           NaN          NaN     NaN    NaN          NaN        NaN
# 30           8.0  Maruti Alto  Maruti   Alto            3      29000
# 31           9.0  Maruti Alto  Maruti   Alto            8      68000
# 32           NaN          NaN     NaN    NaN          NaN        NaN
# 33           NaN          NaN     NaN    NaN          NaN        NaN
# 34           NaN          NaN     NaN    NaN          NaN        NaN
# 35           NaN          NaN     NaN    NaN          NaN        NaN
# 36          10.0  Maruti Alto  Maruti   Alto            4      20700
# 37          14.0  Maruti Alto  Maruti   Alto            4      61000
# 38           NaN          NaN     NaN    NaN          NaN        NaN
# 39           NaN          NaN     NaN    NaN          NaN        NaN
#
#           NaN.5      NaN.6              NaN.7    NaN.8   NaN.9     NaN.10  \
# 0           NaN        NaN                NaN      NaN     NaN        NaN
# 1           NaN        NaN                NaN      NaN     NaN        NaN
# 2           NaN        NaN                NaN      NaN     NaN        NaN
# 3           NaN        NaN                NaN      NaN     NaN        NaN
# 4           NaN        NaN                NaN      NaN     NaN        NaN
# 5           NaN        NaN                NaN      NaN     NaN        NaN
# 6           NaN        NaN                NaN      NaN     NaN        NaN
# 7           NaN        NaN                NaN      NaN     NaN        NaN
# 8           NaN        NaN                NaN      NaN     NaN        NaN
# 9           NaN        NaN                NaN      NaN     NaN        NaN
# 10  seller_type  fuel_type  transmission_type  mileage  engine  max_power
# 11       Dealer        CNG             Manual    26.83     796       38.4
# 12       Dealer        CNG             Manual    26.83     796       38.4
# 13       Dealer        CNG             Manual    26.83     796       38.4
# 14          NaN        NaN                NaN      NaN     NaN        NaN
# 15          NaN        NaN                NaN      NaN     NaN        NaN
# 16          NaN        NaN                NaN      NaN     NaN        NaN
# 17          NaN        NaN                NaN      NaN     NaN        NaN
# 18       Dealer        CNG             Manual    26.83     796       38.4
# 19   Individual        CNG             Manual    26.83     796       38.4
# 20          NaN        NaN                NaN      NaN     NaN        NaN
# 21          NaN        NaN                NaN      NaN     NaN        NaN
# 22          NaN        NaN                NaN      NaN     NaN        NaN
# 23          NaN        NaN                NaN      NaN     NaN        NaN
# 24       Dealer        CNG             Manual    33.44     796       40.3
# 25       Dealer        CNG             Manual    33.44     796       40.3
# 26          NaN        NaN                NaN      NaN     NaN        NaN
# 27          NaN        NaN                NaN      NaN     NaN        NaN
# 28          NaN        NaN                NaN      NaN     NaN        NaN
# 29          NaN        NaN                NaN      NaN     NaN        NaN
# 30       Dealer        CNG             Manual    33.44     796       40.3
# 31       Dealer        CNG             Manual    33.44     796       40.3
# 32          NaN        NaN                NaN      NaN     NaN        NaN
# 33          NaN        NaN                NaN      NaN     NaN        NaN
# 34          NaN        NaN                NaN      NaN     NaN        NaN
# 35          NaN        NaN                NaN      NaN     NaN        NaN
# 36       Dealer        CNG             Manual    33.44     796       40.3
# 37       Dealer        CNG             Manual    33.44     796       40.3
# 38          NaN        NaN                NaN      NaN     NaN        NaN
# 39          NaN        NaN                NaN      NaN     NaN        NaN
#
#    NaN.11         NaN.12 Unnamed: 14
# 0     NaN            NaN         NaN
# 1     NaN            NaN         NaN
# 2     NaN            NaN         NaN
# 3     NaN            NaN         NaN
# 4     NaN            NaN         NaN
# 5     NaN            NaN         NaN
# 6     NaN            NaN         NaN
# 7     NaN            NaN         NaN
# 8     NaN            NaN         NaN
# 9     NaN            NaN         NaN
# 10  seats  selling_price      my_car
# 11      5         235000         NaN
# 12      5         185000         NaN
# 13      5         150000         NaN
# 14    NaN            NaN         NaN
# 15    NaN            NaN         NaN
# 16    NaN            NaN         NaN
# 17    NaN            NaN         NaN
# 18      5         172000         NaN
# 19      5         125000         NaN
# 20    NaN            NaN         NaN
# 21    NaN            NaN         NaN
# 22    NaN            NaN         NaN
# 23    NaN            NaN         NaN
# 24      4         260000         NaN
# 25      4         281000         NaN
# 26    NaN            NaN         NaN
# 27    NaN            NaN         NaN
# 28    NaN            NaN         NaN
# 29    NaN            NaN         NaN
# 30      4         345000         NaN
# 31      4         150000         NaN
# 32    NaN            NaN         NaN
# 33    NaN            NaN         NaN
# 34    NaN            NaN         NaN
# 35    NaN            NaN         NaN
# 36      4         381000         NaN
# 37      4         340000         NaN
# 38    NaN            NaN         NaN
# 39    NaN            NaN         NaN

# %%
df = pd.read_csv('./data/cars_dataset.csv', header=11)
df
# Out:
#            NaN             car_name        brand        model  vehicle_age  \
# 0          1.0          Maruti Alto       Maruti         Alto          9.0
# 1          2.0          Maruti Alto       Maruti         Alto         11.0
# 2          3.0          Maruti Alto       Maruti         Alto         11.0
# 3          NaN                  NaN          NaN          NaN          NaN
# 4          NaN                  NaN          NaN          NaN          NaN
# ...        ...                  ...          ...          ...          ...
# 15796  30016.0  Bentley Continental      Bentley  Continental         10.0
# 15797  30017.0    Rolls-Royce Ghost  Rolls-Royce        Ghost          4.0
# 15798  30018.0  Bentley Continental      Bentley  Continental          9.0
# 15799  30019.0    Ferrari GTC4Lusso      Ferrari    GTC4Lusso          2.0
# 15800  30020.0  Bentley Continental      Bentley  Continental          9.0
#
#        km_driven seller_type fuel_type transmission_type  mileage  engine  \
# 0        53800.0      Dealer       CNG            Manual    26.83   796.0
# 1        11000.0      Dealer       CNG            Manual    26.83   796.0
# 2        80000.0      Dealer       CNG            Manual    26.83   796.0
# 3            NaN         NaN       NaN               NaN      NaN     NaN
# 4            NaN         NaN       NaN               NaN      NaN     NaN
# ...          ...         ...       ...               ...      ...     ...
# 15796    30000.0      Dealer    Petrol         Automatic     8.60  5998.0
# 15797     5000.0  Individual    Petrol         Automatic    10.20  6592.0
# 15798    37500.0      Dealer    Petrol         Automatic     6.00  5998.0
# 15799     3800.0      Dealer    Petrol         Automatic     4.00  3855.0
# 15800     9000.0      Dealer    Petrol         Automatic     9.50  5998.0
#
#        max_power  seats  selling_price   my_car
# 0           38.4    5.0       235000.0      NaN
# 1           38.4    5.0       185000.0      NaN
# 2           38.4    5.0       150000.0      NaN
# 3            NaN    NaN            NaN      NaN
# 4            NaN    NaN            NaN      NaN
# ...          ...    ...            ...      ...
# 15796      552.0    4.0      8100000.0      NaN
# 15797      563.0    4.0     24200000.0      NaN
# 15798      600.0    5.0      5200000.0      NaN
# 15799      601.0    4.0     39500000.0      NaN
# 15800      626.0    4.0     14500000.0      NaN
#
# [15801 rows x 15 columns]

# %%
df.isnull().sum()
# Out:
# NaN                    390
# car_name               390
# brand                  390
# model                  390
# vehicle_age            390
# km_driven              390
# seller_type            390
# fuel_type              390
# transmission_type      390
# mileage                390
# engine                 390
# max_power              390
# seats                  390
# selling_price          390
#  my_car              15801
# dtype: int64

# %%
df.drop(' my_car',axis=1, inplace=True)

# %%
df
# Out:
#            NaN             car_name        brand        model  vehicle_age  \
# 0          1.0          Maruti Alto       Maruti         Alto          9.0
# 1          2.0          Maruti Alto       Maruti         Alto         11.0
# 2          3.0          Maruti Alto       Maruti         Alto         11.0
# 3          NaN                  NaN          NaN          NaN          NaN
# 4          NaN                  NaN          NaN          NaN          NaN
# ...        ...                  ...          ...          ...          ...
# 15796  30016.0  Bentley Continental      Bentley  Continental         10.0
# 15797  30017.0    Rolls-Royce Ghost  Rolls-Royce        Ghost          4.0
# 15798  30018.0  Bentley Continental      Bentley  Continental          9.0
# 15799  30019.0    Ferrari GTC4Lusso      Ferrari    GTC4Lusso          2.0
# 15800  30020.0  Bentley Continental      Bentley  Continental          9.0
#
#        km_driven seller_type fuel_type transmission_type  mileage  engine  \
# 0        53800.0      Dealer       CNG            Manual    26.83   796.0
# 1        11000.0      Dealer       CNG            Manual    26.83   796.0
# 2        80000.0      Dealer       CNG            Manual    26.83   796.0
# 3            NaN         NaN       NaN               NaN      NaN     NaN
# 4            NaN         NaN       NaN               NaN      NaN     NaN
# ...          ...         ...       ...               ...      ...     ...
# 15796    30000.0      Dealer    Petrol         Automatic     8.60  5998.0
# 15797     5000.0  Individual    Petrol         Automatic    10.20  6592.0
# 15798    37500.0      Dealer    Petrol         Automatic     6.00  5998.0
# 15799     3800.0      Dealer    Petrol         Automatic     4.00  3855.0
# 15800     9000.0      Dealer    Petrol         Automatic     9.50  5998.0
#
#        max_power  seats  selling_price
# 0           38.4    5.0       235000.0
# 1           38.4    5.0       185000.0
# 2           38.4    5.0       150000.0
# 3            NaN    NaN            NaN
# 4            NaN    NaN            NaN
# ...          ...    ...            ...
# 15796      552.0    4.0      8100000.0
# 15797      563.0    4.0     24200000.0
# 15798      600.0    5.0      5200000.0
# 15799      601.0    4.0     39500000.0
# 15800      626.0    4.0     14500000.0
#
# [15801 rows x 14 columns]

# %%
df
# Out:
#            NaN             car_name        brand        model  vehicle_age  \
# 0          1.0          Maruti Alto       Maruti         Alto          9.0
# 1          2.0          Maruti Alto       Maruti         Alto         11.0
# 2          3.0          Maruti Alto       Maruti         Alto         11.0
# 3          NaN                  NaN          NaN          NaN          NaN
# 4          NaN                  NaN          NaN          NaN          NaN
# ...        ...                  ...          ...          ...          ...
# 15796  30016.0  Bentley Continental      Bentley  Continental         10.0
# 15797  30017.0    Rolls-Royce Ghost  Rolls-Royce        Ghost          4.0
# 15798  30018.0  Bentley Continental      Bentley  Continental          9.0
# 15799  30019.0    Ferrari GTC4Lusso      Ferrari    GTC4Lusso          2.0
# 15800  30020.0  Bentley Continental      Bentley  Continental          9.0
#
#        km_driven seller_type fuel_type transmission_type  mileage  engine  \
# 0        53800.0      Dealer       CNG            Manual    26.83   796.0
# 1        11000.0      Dealer       CNG            Manual    26.83   796.0
# 2        80000.0      Dealer       CNG            Manual    26.83   796.0
# 3            NaN         NaN       NaN               NaN      NaN     NaN
# 4            NaN         NaN       NaN               NaN      NaN     NaN
# ...          ...         ...       ...               ...      ...     ...
# 15796    30000.0      Dealer    Petrol         Automatic     8.60  5998.0
# 15797     5000.0  Individual    Petrol         Automatic    10.20  6592.0
# 15798    37500.0      Dealer    Petrol         Automatic     6.00  5998.0
# 15799     3800.0      Dealer    Petrol         Automatic     4.00  3855.0
# 15800     9000.0      Dealer    Petrol         Automatic     9.50  5998.0
#
#        max_power  seats  selling_price
# 0           38.4    5.0       235000.0
# 1           38.4    5.0       185000.0
# 2           38.4    5.0       150000.0
# 3            NaN    NaN            NaN
# 4            NaN    NaN            NaN
# ...          ...    ...            ...
# 15796      552.0    4.0      8100000.0
# 15797      563.0    4.0     24200000.0
# 15798      600.0    5.0      5200000.0
# 15799      601.0    4.0     39500000.0
# 15800      626.0    4.0     14500000.0
#
# [15801 rows x 14 columns]

# %%
df.dtypes
# Out:
# NaN                  float64
# car_name              object
# brand                 object
# model                 object
# vehicle_age          float64
# km_driven            float64
# seller_type           object
# fuel_type             object
# transmission_type     object
# mileage              float64
# engine               float64
# max_power            float64
# seats                float64
# selling_price        float64
# dtype: object

# %%
df.drop('NaN',axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# car_name             390
# brand                390
# model                390
# vehicle_age          390
# km_driven            390
# seller_type          390
# fuel_type            390
# transmission_type    390
# mileage              390
# engine               390
# max_power            390
# seats                390
# selling_price        390
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#                   car_name        brand        model  vehicle_age  km_driven  \
# 0              Maruti Alto       Maruti         Alto          9.0    53800.0
# 1              Maruti Alto       Maruti         Alto         11.0    11000.0
# 2              Maruti Alto       Maruti         Alto         11.0    80000.0
# 7              Maruti Alto       Maruti         Alto         10.0    57000.0
# 8              Maruti Alto       Maruti         Alto         11.0    72000.0
# ...                    ...          ...          ...          ...        ...
# 15796  Bentley Continental      Bentley  Continental         10.0    30000.0
# 15797    Rolls-Royce Ghost  Rolls-Royce        Ghost          4.0     5000.0
# 15798  Bentley Continental      Bentley  Continental          9.0    37500.0
# 15799    Ferrari GTC4Lusso      Ferrari    GTC4Lusso          2.0     3800.0
# 15800  Bentley Continental      Bentley  Continental          9.0     9000.0
#
#       seller_type fuel_type transmission_type  mileage  engine  max_power  \
# 0          Dealer       CNG            Manual    26.83   796.0       38.4
# 1          Dealer       CNG            Manual    26.83   796.0       38.4
# 2          Dealer       CNG            Manual    26.83   796.0       38.4
# 7          Dealer       CNG            Manual    26.83   796.0       38.4
# 8      Individual       CNG            Manual    26.83   796.0       38.4
# ...           ...       ...               ...      ...     ...        ...
# 15796      Dealer    Petrol         Automatic     8.60  5998.0      552.0
# 15797  Individual    Petrol         Automatic    10.20  6592.0      563.0
# 15798      Dealer    Petrol         Automatic     6.00  5998.0      600.0
# 15799      Dealer    Petrol         Automatic     4.00  3855.0      601.0
# 15800      Dealer    Petrol         Automatic     9.50  5998.0      626.0
#
#        seats  selling_price
# 0        5.0       235000.0
# 1        5.0       185000.0
# 2        5.0       150000.0
# 7        5.0       172000.0
# 8        5.0       125000.0
# ...      ...            ...
# 15796    4.0      8100000.0
# 15797    4.0     24200000.0
# 15798    5.0      5200000.0
# 15799    4.0     39500000.0
# 15800    4.0     14500000.0
#
# [15411 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# car_name             0
# brand                0
# model                0
# vehicle_age          0
# km_driven            0
# seller_type          0
# fuel_type            0
# transmission_type    0
# mileage              0
# engine               0
# max_power            0
# seats                0
# selling_price        0
# dtype: int64

# %%
df.dtypes
# Out:
# car_name              object
# brand                 object
# model                 object
# vehicle_age          float64
# km_driven            float64
# seller_type           object
# fuel_type             object
# transmission_type     object
# mileage              float64
# engine               float64
# max_power            float64
# seats                float64
# selling_price        float64
# dtype: object

# %%
df.columns
# Out:
# Index(['car_name', 'brand', 'model', 'vehicle_age', 'km_driven', 'seller_type',
#        'fuel_type', 'transmission_type', 'mileage', 'engine', 'max_power',
#        'seats', 'selling_price'],
#       dtype='object')

# %%
df
# Out:
#                   car_name        brand        model  vehicle_age  km_driven  \
# 0              Maruti Alto       Maruti         Alto          9.0    53800.0
# 1              Maruti Alto       Maruti         Alto         11.0    11000.0
# 2              Maruti Alto       Maruti         Alto         11.0    80000.0
# 7              Maruti Alto       Maruti         Alto         10.0    57000.0
# 8              Maruti Alto       Maruti         Alto         11.0    72000.0
# ...                    ...          ...          ...          ...        ...
# 15796  Bentley Continental      Bentley  Continental         10.0    30000.0
# 15797    Rolls-Royce Ghost  Rolls-Royce        Ghost          4.0     5000.0
# 15798  Bentley Continental      Bentley  Continental          9.0    37500.0
# 15799    Ferrari GTC4Lusso      Ferrari    GTC4Lusso          2.0     3800.0
# 15800  Bentley Continental      Bentley  Continental          9.0     9000.0
#
#       seller_type fuel_type transmission_type  mileage  engine  max_power  \
# 0          Dealer       CNG            Manual    26.83   796.0       38.4
# 1          Dealer       CNG            Manual    26.83   796.0       38.4
# 2          Dealer       CNG            Manual    26.83   796.0       38.4
# 7          Dealer       CNG            Manual    26.83   796.0       38.4
# 8      Individual       CNG            Manual    26.83   796.0       38.4
# ...           ...       ...               ...      ...     ...        ...
# 15796      Dealer    Petrol         Automatic     8.60  5998.0      552.0
# 15797  Individual    Petrol         Automatic    10.20  6592.0      563.0
# 15798      Dealer    Petrol         Automatic     6.00  5998.0      600.0
# 15799      Dealer    Petrol         Automatic     4.00  3855.0      601.0
# 15800      Dealer    Petrol         Automatic     9.50  5998.0      626.0
#
#        seats  selling_price
# 0        5.0       235000.0
# 1        5.0       185000.0
# 2        5.0       150000.0
# 7        5.0       172000.0
# 8        5.0       125000.0
# ...      ...            ...
# 15796    4.0      8100000.0
# 15797    4.0     24200000.0
# 15798    5.0      5200000.0
# 15799    4.0     39500000.0
# 15800    4.0     14500000.0
#
# [15411 rows x 13 columns]

# %%
df.columns
# Out:
# Index(['car_name', 'brand', 'model', 'vehicle_age', 'km_driven', 'seller_type',
#        'fuel_type', 'transmission_type', 'mileage', 'engine', 'max_power',
#        'seats', 'selling_price'],
#       dtype='object')

# %%
df[['vehicle_age','km_driven','engine','seats','selling_price']] = df[['vehicle_age','km_driven','engine','seats','selling_price']].astype(int)

# %%
df
# Out:
#                   car_name        brand        model  vehicle_age  km_driven  \
# 0              Maruti Alto       Maruti         Alto            9      53800
# 1              Maruti Alto       Maruti         Alto           11      11000
# 2              Maruti Alto       Maruti         Alto           11      80000
# 7              Maruti Alto       Maruti         Alto           10      57000
# 8              Maruti Alto       Maruti         Alto           11      72000
# ...                    ...          ...          ...          ...        ...
# 15796  Bentley Continental      Bentley  Continental           10      30000
# 15797    Rolls-Royce Ghost  Rolls-Royce        Ghost            4       5000
# 15798  Bentley Continental      Bentley  Continental            9      37500
# 15799    Ferrari GTC4Lusso      Ferrari    GTC4Lusso            2       3800
# 15800  Bentley Continental      Bentley  Continental            9       9000
#
#       seller_type fuel_type transmission_type  mileage  engine  max_power  \
# 0          Dealer       CNG            Manual    26.83     796       38.4
# 1          Dealer       CNG            Manual    26.83     796       38.4
# 2          Dealer       CNG            Manual    26.83     796       38.4
# 7          Dealer       CNG            Manual    26.83     796       38.4
# 8      Individual       CNG            Manual    26.83     796       38.4
# ...           ...       ...               ...      ...     ...        ...
# 15796      Dealer    Petrol         Automatic     8.60    5998      552.0
# 15797  Individual    Petrol         Automatic    10.20    6592      563.0
# 15798      Dealer    Petrol         Automatic     6.00    5998      600.0
# 15799      Dealer    Petrol         Automatic     4.00    3855      601.0
# 15800      Dealer    Petrol         Automatic     9.50    5998      626.0
#
#        seats  selling_price
# 0          5         235000
# 1          5         185000
# 2          5         150000
# 7          5         172000
# 8          5         125000
# ...      ...            ...
# 15796      4        8100000
# 15797      4       24200000
# 15798      5        5200000
# 15799      4       39500000
# 15800      4       14500000
#
# [15411 rows x 13 columns]

# %%
#selling price by fuel type 

df.groupby('fuel_type')['selling_price'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='fuel_type'>

# %%
df
# Out:
#                   car_name        brand        model  vehicle_age  km_driven  \
# 0              Maruti Alto       Maruti         Alto            9      53800
# 1              Maruti Alto       Maruti         Alto           11      11000
# 2              Maruti Alto       Maruti         Alto           11      80000
# 7              Maruti Alto       Maruti         Alto           10      57000
# 8              Maruti Alto       Maruti         Alto           11      72000
# ...                    ...          ...          ...          ...        ...
# 15796  Bentley Continental      Bentley  Continental           10      30000
# 15797    Rolls-Royce Ghost  Rolls-Royce        Ghost            4       5000
# 15798  Bentley Continental      Bentley  Continental            9      37500
# 15799    Ferrari GTC4Lusso      Ferrari    GTC4Lusso            2       3800
# 15800  Bentley Continental      Bentley  Continental            9       9000
#
#       seller_type fuel_type transmission_type  mileage  engine  max_power  \
# 0          Dealer       CNG            Manual    26.83     796       38.4
# 1          Dealer       CNG            Manual    26.83     796       38.4
# 2          Dealer       CNG            Manual    26.83     796       38.4
# 7          Dealer       CNG            Manual    26.83     796       38.4
# 8      Individual       CNG            Manual    26.83     796       38.4
# ...           ...       ...               ...      ...     ...        ...
# 15796      Dealer    Petrol         Automatic     8.60    5998      552.0
# 15797  Individual    Petrol         Automatic    10.20    6592      563.0
# 15798      Dealer    Petrol         Automatic     6.00    5998      600.0
# 15799      Dealer    Petrol         Automatic     4.00    3855      601.0
# 15800      Dealer    Petrol         Automatic     9.50    5998      626.0
#
#        seats  selling_price
# 0          5         235000
# 1          5         185000
# 2          5         150000
# 7          5         172000
# 8          5         125000
# ...      ...            ...
# 15796      4        8100000
# 15797      4       24200000
# 15798      5        5200000
# 15799      4       39500000
# 15800      4       14500000
#
# [15411 rows x 13 columns]

# %%
df.to_csv('./data/cleaned_cars_dataset.csv', index=False)

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine(
    'mysql+pymysql://{user}:{password}@{host}:{port}/{database}'.format(
        user='root',
        password='12345678',
        host='localhost',
        port=3306,
        database='car_price_prediction_db'
    )
)

# %%
df.to_sql(con =engine , name = 'car_price_prediction_db', index=False , if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df.to_sql(con =engine , name = 'car_price_prediction_db', index=False , if_exists='replace')
#
# File ~/Desktop/CarPricePrediction/carPriceVenv/lib/python3.9/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/Desktop/CarPricePrediction/carPriceVenv/lib/python3.9/site-packages/pandas/core/generic.py:3109, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2911 """
#    2912 Write records stored in a DataFrame to a SQL database.
#    2913
#    (...)
#    3105 [(1,), (None,), (2,)]
#    3106 """  # noqa: E501
#    3107 from pandas.io import sql
# -> 3109 return sql.to_sql(
#    3110     self,
#    3111     name,
#    3112     con,
#    3113     schema=schema,
#    3114     if_exists=if_exists,
#    3115     index=index,
#    3116     index_label=index_label,
#    3117     chunksize=chunksize,
#    3118     dtype=dtype,
#    3119     method=method,
#    3120 )
#
# File ~/Desktop/CarPricePrediction/carPriceVenv/lib/python3.9/site-packages/pandas/io/sql.py:843, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     838 elif not isinstance(frame, DataFrame):
#     839     raise NotImplementedError(
#     840         "'frame' argument should be either a Series or a DataFrame"
#     841     )
# --> 843 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
#     844     return pandas_sql.to_sql(
#     845         frame,
#     846         name,
#    (...)
#     855         **engine_kwargs,
#     856     )
#
# File ~/Desktop/CarPricePrediction/carPriceVenv/lib/python3.9/site-packages/pandas/io/sql.py:908, in pandasSQL_builder(con, schema, need_transaction)
#     905     raise ImportError("Using URI string without sqlalchemy installed.")
#     907 if sqlalchemy is not None and isinstance(con, (str, sqlalchemy.engine.Connectable)):
# --> 908     return SQLDatabase(con, schema, need_transaction)
#     910 adbc = import_optional_dependency("adbc_driver_manager.dbapi", errors="ignore")
#     911 if adbc and isinstance(con, adbc.Connection):
#
# File ~/Desktop/CarPricePrediction/carPriceVenv/lib/python3.9/site-packages/pandas/io/sql.py:1648, in SQLDatabase.__init__(self, con, schema, need_transaction)
#    1646     self.exit_stack.callback(con.dispose)
#    1647 if isinstance(con, Engine):
# -> 1648     con = self.exit_stack.enter_context(con.connect())
#    1649 if need_transaction and not con.in_transaction():
#    1650     self.exit_stack.enter_context(con.begin())
#
# File ~/Desktop/CarPricePrediction/carPriceVenv/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3285, in Engine.connect(self)
#    3262 def connect(self) -> Connection:
#    3263     """Return a new :class:`_engine.Connection` object.
#    3264
#    3265     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)
#    3282
#    3283     """
# -> 3285     return self._connection_cls(self)
#
# File ~/Desktop/CarPricePrediction/carPriceVenv/lib/python3.9/site-packages/sqlalchemy/engine/base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     141 if connection is None:
#     142     try:
# --> 143         self._dbapi_connection = engine.raw_connection()
#     144     except dialect.loaded_dbapi.Error as err:
#     145         Connection._handle_dbapi_exception_noconnection(
#     146             err, dialect, engine
#     147         )
#
# File ~/Desktop/CarPricePrediction/carPriceVenv/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3309, in Engine.raw_connection(self)
#    3287 def raw_connection(self) -> PoolProxiedConnection:
#    3288     """Return a "raw" DBAPI connection from the connection pool.
#    3289
#    3290     The returned object is a proxied version of the DBAPI
#    (...)
#    3307
#    3308     """
# -> 3309     return self.pool.connect()
#
# File ~/Desktop/CarPricePrediction/carPriceVenv/lib/python3.9/site-packages/sqlalchemy/pool/base.py:447, in Pool.connect(self)
#     439 def connect(self) -> PoolProxiedConnection:
#     440     """Return a DBAPI connection from the pool.
#     441
#     442     The connection is instrumented such that when its
#    (...)
#     445
#     446     """
# --> 447     return _ConnectionFairy._checkout(self)
#
# File ~/Desktop/CarPricePrediction/carPriceVenv/lib/python3.9/site-packages/sqlalchemy/pool/base.py:1264, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1256 @classmethod
#    1257 def _checkout(
#    1258     cls,
#    (...)
#    1261     fairy: Optional[_ConnectionFairy] = None,
#    1262 ) -> _ConnectionFairy:
#    1263     if not fairy:
# -> 1264         fairy = _ConnectionRecord.checkout(pool)
#    1266         if threadconns is not None:
#    1267             threadconns.current = weakref.ref(fairy)
#
# File ~/Desktop/CarPricePrediction/carPriceVenv/lib/python3.9/site-packages/sqlalchemy/pool/base.py:711, in _ConnectionRecord.checkout(cls, pool)
#     709     rec = cast(_ConnectionRecord, pool._do_get())
#     710 else:
# --> 711     rec = pool._do_get()
#     713 try:
#     714     dbapi_connection = rec.get_connection()
#
# File ~/Desktop/CarPricePrediction/carPriceVenv/lib/python3.9/site-packages/sqlalchemy/pool/impl.py:178, in QueuePool._do_get(self)
#     176     except:
#     177         with util.safe_reraise():
# --> 178             self._dec_overflow()
#     179         raise
#     180 else:
#
# File ~/Desktop/CarPricePrediction/carPriceVenv/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     222     assert exc_value is not None
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#     226     self._exc_info = None  # remove potential circular references
#
# File ~/Desktop/CarPricePrediction/carPriceVenv/lib/python3.9/site-packages/sqlalchemy/pool/impl.py:175, in QueuePool._do_get(self)
#     173 if self._inc_overflow():
#     174     try:
# --> 175         return self._create_connection()
#     176     except:
#     177         with util.safe_reraise():
#
# File ~/Desktop/CarPricePrediction/carPriceVenv/lib/python3.9/site-packages/sqlalchemy/pool/base.py:388, in Pool._create_connection(self)
#     385 def _create_connection(self) -> ConnectionPoolEntry:
#     386     """Called by subclasses to create a new ConnectionRecord."""
# --> 388     return _ConnectionRecord(self)
#
# File ~/Desktop/CarPricePrediction/carPriceVenv/lib/python3.9/site-packages/sqlalchemy/pool/base.py:673, in _ConnectionRecord.__init__(self, pool, connect)
#     671 self.__pool = pool
#     672 if connect:
# --> 673     self.__connect()
#     674 self.finalize_callback = deque()
#
# File ~/Desktop/CarPricePrediction/carPriceVenv/lib/python3.9/site-packages/sqlalchemy/pool/base.py:900, in _ConnectionRecord.__connect(self)
#     898 except BaseException as e:
#     899     with util.safe_reraise():
# --> 900         pool.logger.debug("Error on connect(): %s", e)
#     901 else:
#     902     # in SQLAlchemy 1.4 the first_connect event is not used by
#     903     # the engine, so this will usually not be set
#     904     if pool.dispatch.first_connect:
#
# File ~/Desktop/CarPricePrediction/carPriceVenv/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     222     assert exc_value is not None
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#     226     self._exc_info = None  # remove potential circular references
#
# File ~/Desktop/CarPricePrediction/carPriceVenv/lib/python3.9/site-packages/sqlalchemy/pool/base.py:895, in _ConnectionRecord.__connect(self)
#     893 try:
#     894     self.starttime = time.time()
# --> 895     self.dbapi_connection = connection = pool._invoke_creator(self)
#     896     pool.logger.debug("Created new connection %r", connection)
#     897     self.fresh = True
#
# File ~/Desktop/CarPricePrediction/carPriceVenv/lib/python3.9/site-packages/sqlalchemy/engine/create.py:661, in create_engine.<locals>.connect(connection_record)
#     658         if connection is not None:
#     659             return connection
# --> 661 return dialect.connect(*cargs, **cparams)
#
# File ~/Desktop/CarPricePrediction/carPriceVenv/lib/python3.9/site-packages/sqlalchemy/engine/default.py:630, in DefaultDialect.connect(self, *cargs, **cparams)
#     628 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     629     # inherits the docstring from interfaces.Dialect.connect
# --> 630     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~/Desktop/CarPricePrediction/carPriceVenv/lib/python3.9/site-packages/pymysql/connections.py:365, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, collation, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_key_password, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     363     self._sock = None
#     364 else:
# --> 365     self.connect()
#
# File ~/Desktop/CarPricePrediction/carPriceVenv/lib/python3.9/site-packages/pymysql/connections.py:681, in Connection.connect(self, sock)
#     678 self._next_seq_id = 0
#     680 self._get_server_information()
# --> 681 self._request_authentication()
#     683 # Send "SET NAMES" query on init for:
#     684 # - Ensure charaset (and collation) is set to the server.
#     685 #   - collation_id in handshake packet may be ignored.
#    (...)
#     694 # - https://github.com/wagtail/wagtail/issues/9477
#     695 # - https://zenn.dev/methane/articles/2023-mysql-collation (Japanese)
#     696 self.set_character_set(self.charset, self.collation)
#
# File ~/Desktop/CarPricePrediction/carPriceVenv/lib/python3.9/site-packages/pymysql/connections.py:980, in Connection._request_authentication(self)
#     978 # https://dev.mysql.com/doc/internals/en/successful-authentication.html
#     979 if self._auth_plugin_name == "caching_sha2_password":
# --> 980     auth_packet = _auth.caching_sha2_password_auth(self, auth_packet)
#     981 elif self._auth_plugin_name == "sha256_password":
#     982     auth_packet = _auth.sha256_password_auth(self, auth_packet)
#
# File ~/Desktop/CarPricePrediction/carPriceVenv/lib/python3.9/site-packages/pymysql/_auth.py:271, in caching_sha2_password_auth(conn, pkt)
#     268     if DEBUG:
#     269         print(conn.server_public_key.decode("ascii"))
# --> 271 data = sha2_rsa_encrypt(conn.password, conn.salt, conn.server_public_key)
#     272 pkt = _roundtrip(conn, data)
#
# File ~/Desktop/CarPricePrediction/carPriceVenv/lib/python3.9/site-packages/pymysql/_auth.py:144, in sha2_rsa_encrypt(password, salt, public_key)
#     139 """Encrypt password with salt and public_key.
#     140
#     141 Used for sha256_password and caching_sha2_password.
#     142 """
#     143 if not _have_cryptography:
# --> 144     raise RuntimeError(
#     145         "'cryptography' package is required for sha256_password or"
#     146         + " caching_sha2_password auth methods"
#     147     )
#     148 message = _xor_password(password + b"\0", salt)
#     149 rsa_key = serialization.load_pem_public_key(public_key, default_backend())
#
# RuntimeError: 'cryptography' package is required for sha256_password or caching_sha2_password auth methods

# %%
df['car_name'].dtype =='O'
# Out:
# True

# %%
df['vehicle_age'].dtype !='O'
# Out:
# True

# %%
df['max_power'].dtype !='O'
# Out:
# True

# %%
numerical_features = [feature for feature in df.columns if df[feature].dtype !='O']
categorical_features = [feature for feature in df.columns if df[feature].dtype =='O']

print(f"There are {len(numerical_features)} numerical features named as: {numerical_features}")
print(f"There are {len(categorical_features)} categorical features named as: {categorical_features}")
# Out:
# There are 7 numerical features named as: ['vehicle_age', 'km_driven', 'mileage', 'engine', 'max_power', 'seats', 'selling_price']
# There are 6 categorical features named as: ['car_name', 'brand', 'model', 'seller_type', 'fuel_type', 'transmission_type']

# %%
#univeraint analysi

# %%
plt.figure(figsize=(15,10))
plt.suptitle('Univariant Analysis on Numerical Features', fontsize= 20)
for i in range(len(numerical_features)):
    plt.subplot(4,4,i+1)
    sns.kdeplot(x=df[numerical_features[i]], color='r', shade=True)
    plt.tight_layout()

# %%
#outlisrerfs

# %%
plt.figure(figsize=(15,10))
plt.suptitle('Outliears detection on Numerical Features', fontsize= 20)
for i in range(len(numerical_features)):
    plt.subplot(4,4,i+1)
    sns.boxplot(x=df[numerical_features[i]], color='r')
    plt.tight_layout()

# %%
#use of kde

# %%
plt.figure(figsize=(15,10))
plt.suptitle('Outliears detection on Numerical Features', fontsize= 20)
for i in range(len(numerical_features)):
    plt.subplot(4,4,i+1)
    sns.histplot(x=df[numerical_features[i]], color='r', kde=True)
    plt.tight_layout()

# %%
#bivariant analususi

# %%
plt.figure(figsize=(15,10))
plt.suptitle('Bivariate Analysis on Numerical Features',fontsize = 20)
for i in range(len(numerical_features)):
    plt.subplot(4,2,i+1)
    sns.scatterplot(x=df['selling_price'],y=df[numerical_features[i]],color='r')
    plt.tight_layout()

# %%
#multivaesdfs

# %%
df[numerical_features].corr()
# Out:
#                vehicle_age  km_driven   mileage    engine  max_power  \
# vehicle_age       1.000000   0.333891 -0.257394  0.098965   0.005208
# km_driven         0.333891   1.000000 -0.105239  0.192885   0.044421
# mileage          -0.257394  -0.105239  1.000000 -0.632987  -0.533128
# engine            0.098965   0.192885 -0.632987  1.000000   0.807368
# max_power         0.005208   0.044421 -0.533128  0.807368   1.000000
# seats             0.030791   0.192830 -0.440280  0.551236   0.172257
# selling_price    -0.241851  -0.080030 -0.305549  0.585844   0.750236
#
#                   seats  selling_price
# vehicle_age    0.030791      -0.241851
# km_driven      0.192830      -0.080030
# mileage       -0.440280      -0.305549
# engine         0.551236       0.585844
# max_power      0.172257       0.750236
# seats          1.000000       0.115033
# selling_price  0.115033       1.000000

# %%
plt.figure(figsize=(15,10))
plt.suptitle('Multivariant Analysis on Numerical Features', fontsize = 20)

sns.heatmap(df[numerical_features].corr(),annot=True,vmin=-1,vmax=1, cmap='plasma')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,4))
plt.suptitle("Top 10 most sold brand")
Top_10_most_sold_brand = df['brand'].value_counts().head(10)
ax=sns.barplot(x=Top_10_most_sold_brand.index, y=Top_10_most_sold_brand.values, palette="Set1", ec="black")

for i in range(len(Top_10_most_sold_brand)):
    plt.bar_label(ax.containers[i], label_type='edge')
    
plt.ylabel("Top 10 most sold brand")
plt.xlabel("Brand Name")
# Out:
# Text(0.5, 0, 'Brand Name')

# %%
def format_value(value):
    if value>= 10000000:
        return f"{value/10000000:.2f} Cr"
    elif value>= 100000:
        return f"{value/100000:.2f} Lakhs"
    else:
        return str(value)

# %%
plt.figure(figsize=(15,5))

top_10_costlier_cars = df.groupby('car_name')['selling_price'].max().sort_values(ascending=False).head(10)
ax=sns.barplot(x=top_10_costlier_cars.index, y=top_10_costlier_cars, palette="Set1")

formatted_labels = [format_value(i) for i in top_10_costlier_cars.values]
print(formatted_labels)

for bar, label in zip(ax.containers,formatted_labels):
    ax.bar_label(bar,labels=[label],label_type='edge')

plt.xticks(rotation=90)    
    
plt.ylabel("Top 10 costlier car")
plt.xlabel("Brand Name")
# Out:
# ['3.95 Cr', '2.42 Cr', '1.45 Cr', '1.30 Cr', '1.11 Cr', '92.00 Lakhs', '85.00 Lakhs', '82.50 Lakhs', '81.95 Lakhs', '81.00 Lakhs']
# Text(0.5, 0, 'Brand Name')

# %%
#summaeryy

# %%
#km druiveb vs vehccnical afgqe

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(x=df['vehicle_age'],y=df['km_driven'],hue=df['fuel_type'],size=df['transmission_type'],style=df['seats'])
plt.ylim(0,1500000)
plt.xlim(0,16)
# Out:
# (0.0, 16.0)

# %%
df[df['km_driven']==df['km_driven'].max()]
# Out:
#               car_name     brand   model  vehicle_age  km_driven seller_type  \
# 13704  Mahindra XUV500  Mahindra  XUV500            5    3800000      Dealer
#
#       fuel_type transmission_type  mileage  engine  max_power  seats  \
# 13704    Diesel            Manual     16.0    2179      140.0      7
#
#        selling_price
# 13704        1225000

# %%
df[df['vehicle_age']==df['vehicle_age'].max()]
# Out:
#         car_name   brand model  vehicle_age  km_driven seller_type fuel_type  \
# 357  Maruti Alto  Maruti  Alto           29      22612      Dealer    Petrol
#
#     transmission_type  mileage  engine  max_power  seats  selling_price
# 357            Manual    22.05     796       47.3      5          60000

# %%
df[df['brand']=='Maruti'][['car_name', 'km_driven']].max().to_frame()
# Out:
#                     0
# car_name   Maruti XL6
# km_driven      480000

# %%
df[df['vehicle_age']>15][df['fuel_type']=='Diesel'][df['selling_price']>250000]
# Out:
#                     car_name          brand    model  vehicle_age  km_driven  \
# 1492         Mahindra Bolero       Mahindra   Bolero           16     211121
# 1590           Skoda Octavia          Skoda  Octavia           18     133000
# 15365  Mercedes-Benz E-Class  Mercedes-Benz  E-Class           17     126000
#
#       seller_type fuel_type transmission_type  mileage  engine  max_power  \
# 1492   Individual    Diesel            Manual     13.6    2523       63.0
# 1590       Dealer    Diesel            Manual     18.7    1896       66.0
# 15365      Dealer    Diesel         Automatic     11.0    2987      198.5
#
#        seats  selling_price
# 1492       7         300000
# 1590       5         275000
# 15365      5         315000

# %% [markdown]
# ### Selling price by fuel type

# %%
fuel = df.groupby('fuel_type')['selling_price'].median().sort_values(ascending=False)
ax = sns.barplot(x = fuel.index, y=fuel.values, palette='Set1')

formatted_labels = [format_value(i) for i in fuel.values]

for bar, label in zip(ax.containers, formatted_labels):
    ax.bar_label(bar, labels=[label], label_type='edge')

# %% [markdown]
# ### most sold fuel type cars

# %%
plt.figure(figsize=(15,5))
ax = sns.countplot(x=df['fuel_type'], palette='Set1', order=df['fuel_type'].value_counts().index)
formatted_labels = [format_value(i)  for i in df['fuel_type'].value_counts().values]


for bar, label in zip(ax.containers, formatted_labels):
    ax.bar_label(bar, labels=[label], label_type='edge')

# %% [markdown]
# ### selling price by vehicle age

# %%
plt.figure(figsize=(15,5))
sns.lineplot(x=df['vehicle_age'], y=df['selling_price'],color='red')
# Out:
# <Axes: xlabel='vehicle_age', ylabel='selling_price'>

# %% [markdown]
# # Most preferred transmission type Cars

# %%
sns.countplot(x=df['transmission_type'])
# Out:
# <Axes: xlabel='transmission_type', ylabel='count'>

# %% [markdown]
# # Transmission type by selling price in dataset

# %%
sns.barplot(x=df['transmission_type'], y=df['selling_price'], order=df.groupby('transmission_type')['selling_price'].median().sort_values(ascending=False).index)
# Out:
# <Axes: xlabel='transmission_type', ylabel='selling_price'>

# %% [markdown]
# # most preferred seller

# %%
sns.countplot(x=df['seller_type'])
# Out:
# <Axes: xlabel='seller_type', ylabel='count'>

# %% [markdown]
# # best seller by selling price in dataset

# %%
sns.barplot(x=df['seller_type'], y=df['selling_price'])
# Out:
# <Axes: xlabel='seller_type', ylabel='selling_price'>

# %% [markdown]
# # Report
# - The selling price column is target column to predict i.e. Regression Problem.
# - There are outliers in some columns like km_driven, vehicle_age, max_power, engine and selling price.
# - Dealers are the highest seller of used cars in dataset
# - Vehicle age has negative impact on selling price.
# - Manual Cars are mostly sold cars but automatic cars have highest selling price

# %% [markdown]
# #  Feature Engineering

# %%
df_model = pd.read_csv('./data/cleaned_cars_dataset.csv')
df_model
# Out:
#                   car_name        brand        model  vehicle_age  km_driven  \
# 0              Maruti Alto       Maruti         Alto            9      53800
# 1              Maruti Alto       Maruti         Alto           11      11000
# 2              Maruti Alto       Maruti         Alto           11      80000
# 3              Maruti Alto       Maruti         Alto           10      57000
# 4              Maruti Alto       Maruti         Alto           11      72000
# ...                    ...          ...          ...          ...        ...
# 15406  Bentley Continental      Bentley  Continental           10      30000
# 15407    Rolls-Royce Ghost  Rolls-Royce        Ghost            4       5000
# 15408  Bentley Continental      Bentley  Continental            9      37500
# 15409    Ferrari GTC4Lusso      Ferrari    GTC4Lusso            2       3800
# 15410  Bentley Continental      Bentley  Continental            9       9000
#
#       seller_type fuel_type transmission_type  mileage  engine  max_power  \
# 0          Dealer       CNG            Manual    26.83     796       38.4
# 1          Dealer       CNG            Manual    26.83     796       38.4
# 2          Dealer       CNG            Manual    26.83     796       38.4
# 3          Dealer       CNG            Manual    26.83     796       38.4
# 4      Individual       CNG            Manual    26.83     796       38.4
# ...           ...       ...               ...      ...     ...        ...
# 15406      Dealer    Petrol         Automatic     8.60    5998      552.0
# 15407  Individual    Petrol         Automatic    10.20    6592      563.0
# 15408      Dealer    Petrol         Automatic     6.00    5998      600.0
# 15409      Dealer    Petrol         Automatic     4.00    3855      601.0
# 15410      Dealer    Petrol         Automatic     9.50    5998      626.0
#
#        seats  selling_price
# 0          5         235000
# 1          5         185000
# 2          5         150000
# 3          5         172000
# 4          5         125000
# ...      ...            ...
# 15406      4        8100000
# 15407      4       24200000
# 15408      5        5200000
# 15409      4       39500000
# 15410      4       14500000
#
# [15411 rows x 13 columns]

# %% [markdown]
# # Remove unnecessary columns

# %%
pd.Categorical(df_model['model'])
# Out:
# ['Alto', 'Alto', 'Alto', 'Alto', 'Alto', ..., 'Continental', 'Ghost', 'Continental', 'GTC4Lusso', 'Continental']
# Length: 15411
# Categories (120, object): ['3', '5', '6', '7', ..., 'Z4', 'i10', 'i20', 'redi-GO']

# %%
df.columns
# Out:
# Index(['car_name', 'brand', 'model', 'vehicle_age', 'km_driven', 'seller_type',
#        'fuel_type', 'transmission_type', 'mileage', 'engine', 'max_power',
#        'seats', 'selling_price'],
#       dtype='object')

# %%
df_model=df_model.drop(['car_name', 'brand', 'model'], axis=1)

# %% [markdown]
# # converting categorical columns into numerical columns

# %%
df_model=pd.get_dummies(df_model, dtype=int)
df_model
# Out:
#        vehicle_age  km_driven  mileage  engine  max_power  seats  \
# 0                9      53800    26.83     796       38.4      5
# 1               11      11000    26.83     796       38.4      5
# 2               11      80000    26.83     796       38.4      5
# 3               10      57000    26.83     796       38.4      5
# 4               11      72000    26.83     796       38.4      5
# ...            ...        ...      ...     ...        ...    ...
# 15406           10      30000     8.60    5998      552.0      4
# 15407            4       5000    10.20    6592      563.0      4
# 15408            9      37500     6.00    5998      600.0      5
# 15409            2       3800     4.00    3855      601.0      4
# 15410            9       9000     9.50    5998      626.0      4
#
#        selling_price  seller_type_Dealer  seller_type_Individual  \
# 0             235000                   1                       0
# 1             185000                   1                       0
# 2             150000                   1                       0
# 3             172000                   1                       0
# 4             125000                   0                       1
# ...              ...                 ...                     ...
# 15406        8100000                   1                       0
# 15407       24200000                   0                       1
# 15408        5200000                   1                       0
# 15409       39500000                   1                       0
# 15410       14500000                   1                       0
#
#        seller_type_Trustmark Dealer  fuel_type_CNG  fuel_type_Diesel  \
# 0                                 0              1                 0
# 1                                 0              1                 0
# 2                                 0              1                 0
# 3                                 0              1                 0
# 4                                 0              1                 0
# ...                             ...            ...               ...
# 15406                             0              0                 0
# 15407                             0              0                 0
# 15408                             0              0                 0
# 15409                             0              0                 0
# 15410                             0              0                 0
#
#        fuel_type_Electric  fuel_type_LPG  fuel_type_Petrol  \
# 0                       0              0                 0
# 1                       0              0                 0
# 2                       0              0                 0
# 3                       0              0                 0
# 4                       0              0                 0
# ...                   ...            ...               ...
# 15406                   0              0                 1
# 15407                   0              0                 1
# 15408                   0              0                 1
# 15409                   0              0                 1
# 15410                   0              0                 1
#
#        transmission_type_Automatic  transmission_type_Manual
# 0                                0                         1
# 1                                0                         1
# 2                                0                         1
# 3                                0                         1
# 4                                0                         1
# ...                            ...                       ...
# 15406                            1                         0
# 15407                            1                         0
# 15408                            1                         0
# 15409                            1                         0
# 15410                            1                         0
#
# [15411 rows x 17 columns]

# %% [markdown]
# # Feature Matrix (Independent variable) and target (dependent variable)

# %%
X = df_model.drop('selling_price', axis=1)
X
# Out:
#        vehicle_age  km_driven  mileage  engine  max_power  seats  \
# 0                9      53800    26.83     796       38.4      5
# 1               11      11000    26.83     796       38.4      5
# 2               11      80000    26.83     796       38.4      5
# 3               10      57000    26.83     796       38.4      5
# 4               11      72000    26.83     796       38.4      5
# ...            ...        ...      ...     ...        ...    ...
# 15406           10      30000     8.60    5998      552.0      4
# 15407            4       5000    10.20    6592      563.0      4
# 15408            9      37500     6.00    5998      600.0      5
# 15409            2       3800     4.00    3855      601.0      4
# 15410            9       9000     9.50    5998      626.0      4
#
#        seller_type_Dealer  seller_type_Individual  \
# 0                       1                       0
# 1                       1                       0
# 2                       1                       0
# 3                       1                       0
# 4                       0                       1
# ...                   ...                     ...
# 15406                   1                       0
# 15407                   0                       1
# 15408                   1                       0
# 15409                   1                       0
# 15410                   1                       0
#
#        seller_type_Trustmark Dealer  fuel_type_CNG  fuel_type_Diesel  \
# 0                                 0              1                 0
# 1                                 0              1                 0
# 2                                 0              1                 0
# 3                                 0              1                 0
# 4                                 0              1                 0
# ...                             ...            ...               ...
# 15406                             0              0                 0
# 15407                             0              0                 0
# 15408                             0              0                 0
# 15409                             0              0                 0
# 15410                             0              0                 0
#
#        fuel_type_Electric  fuel_type_LPG  fuel_type_Petrol  \
# 0                       0              0                 0
# 1                       0              0                 0
# 2                       0              0                 0
# 3                       0              0                 0
# 4                       0              0                 0
# ...                   ...            ...               ...
# 15406                   0              0                 1
# 15407                   0              0                 1
# 15408                   0              0                 1
# 15409                   0              0                 1
# 15410                   0              0                 1
#
#        transmission_type_Automatic  transmission_type_Manual
# 0                                0                         1
# 1                                0                         1
# 2                                0                         1
# 3                                0                         1
# 4                                0                         1
# ...                            ...                       ...
# 15406                            1                         0
# 15407                            1                         0
# 15408                            1                         0
# 15409                            1                         0
# 15410                            1                         0
#
# [15411 rows x 16 columns]

# %%
y= df_model['selling_price']
y
# Out:
# 0          235000
# 1          185000
# 2          150000
# 3          172000
# 4          125000
#            ...
# 15406     8100000
# 15407    24200000
# 15408     5200000
# 15409    39500000
# 15410    14500000
# Name: selling_price, Length: 15411, dtype: int64

# %% [markdown]
# # test train split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=0)

# %%
X_train
# Out:
#        vehicle_age  km_driven  mileage  engine  max_power  seats  \
# 14557            5      43000    19.59    1995     184.00      5
# 9069             7      48000    20.73    1373      91.10      5
# 4546             2       5000    25.32    1198      77.00      6
# 14105            7      60004    19.27    2143     170.00      5
# 14675           10      22800    11.74    1796     186.00      5
# ...            ...        ...      ...     ...        ...    ...
# 13123           11      60000    16.55    1968     140.00      5
# 3264             9      35000    22.07    1199      73.90      5
# 9845             5      72000    21.70    1498      98.96      5
# 10799           11      41000    20.54    1598     103.60      5
# 2732             9      75000    19.81    1086      68.05      5
#
#        seller_type_Dealer  seller_type_Individual  \
# 14557                   1                       0
# 9069                    1                       0
# 4546                    0                       1
# 14105                   1                       0
# 14675                   1                       0
# ...                   ...                     ...
# 13123                   1                       0
# 3264                    0                       1
# 9845                    1                       0
# 10799                   1                       0
# 2732                    1                       0
#
#        seller_type_Trustmark Dealer  fuel_type_CNG  fuel_type_Diesel  \
# 14557                             0              0                 1
# 9069                              0              0                 0
# 4546                              0              0                 1
# 14105                             0              0                 1
# 14675                             0              0                 0
# ...                             ...            ...               ...
# 13123                             0              0                 1
# 3264                              0              0                 1
# 9845                              0              0                 1
# 10799                             0              0                 1
# 2732                              0              0                 0
#
#        fuel_type_Electric  fuel_type_LPG  fuel_type_Petrol  \
# 14557                   0              0                 0
# 9069                    0              0                 1
# 4546                    0              0                 0
# 14105                   0              0                 0
# 14675                   0              0                 1
# ...                   ...            ...               ...
# 13123                   0              0                 0
# 3264                    0              0                 0
# 9845                    0              0                 0
# 10799                   0              0                 0
# 2732                    0              0                 1
#
#        transmission_type_Automatic  transmission_type_Manual
# 14557                            1                         0
# 9069                             0                         1
# 4546                             0                         1
# 14105                            1                         0
# 14675                            1                         0
# ...                            ...                       ...
# 13123                            1                         0
# 3264                             0                         1
# 9845                             0                         1
# 10799                            0                         1
# 2732                             0                         1
#
# [12328 rows x 16 columns]

# %%
X_train.shape
# Out:
# (12328, 16)

# %%
X_test.shape
# Out:
# (3083, 16)

# %%
# standardization

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled= scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[-0.34340311, -0.2368301 , -0.03032915, ..., -0.98999168,
#          1.96890383, -1.96890383],
#        [ 0.31843907, -0.14368077,  0.24281279, ...,  1.0101095 ,
#         -0.50789682,  0.50789682],
#        [-1.33616638, -0.94476498,  1.34256853, ..., -0.98999168,
#         -0.50789682,  0.50789682],
#        ...,
#        [-0.34340311,  0.303436  ,  0.47522305, ..., -0.98999168,
#         -0.50789682,  0.50789682],
#        [ 1.64212343, -0.27408983,  0.19728914, ..., -0.98999168,
#         -0.50789682,  0.50789682],
#        [ 0.98028125,  0.35932559,  0.02238245, ...,  1.0101095 ,
#         -0.50789682,  0.50789682]])

# %%
X_test_scaled
# Out:
# array([[-0.6743242 , -0.47901835,  0.28114851, ...,  1.0101095 ,
#         -0.50789682,  0.50789682],
#        [-0.6743242 , -0.29488076,  0.78670071, ..., -0.98999168,
#         -0.50789682,  0.50789682],
#        [-0.34340311,  0.17302694,  0.67648553, ..., -0.98999168,
#         -0.50789682,  0.50789682],
#        ...,
#        [ 1.64212343,  1.77186061, -0.19565191, ...,  1.0101095 ,
#         -0.50789682,  0.50789682],
#        [-1.33616638, -0.80038352, -0.65088849, ..., -0.98999168,
#         -0.50789682,  0.50789682],
#        [-0.6743242 , -0.47901835,  0.67648553, ..., -0.98999168,
#         -0.50789682,  0.50789682]])

# %% [markdown]
# # checking important features

# %%
from sklearn.ensemble import ExtraTreesRegressor
model = ExtraTreesRegressor()
model.fit(X_train_scaled, y_train)
# Out:
# ExtraTreesRegressor()

# %%
imp_features = pd.Series(model.feature_importances_, index=X_train.columns)
imp_features.nlargest(20).plot(kind='barh', color='g')
# Out:
# <Axes: >

# %% [markdown]
# # model building and evaluation

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, explained_variance_score, r2_score

# %%
models = [LinearRegression, Ridge, Lasso, SVR, DecisionTreeRegressor, RandomForestRegressor]

mae=[]
mse=[]
rmse =[]
evs = []
r_squared_score = []

for model in models:
    regressor = model().fit(X_train_scaled, y_train)
    y_pred = regressor.predict(X_test_scaled)
    print(y_pred)

    mae.append(mean_absolute_error(y_true=y_test, y_pred=y_pred))
    mse.append(mean_squared_error(y_true=y_test, y_pred=y_pred))
    rmse.append(np.sqrt(mean_squared_error(y_true=y_test, y_pred=y_pred)))
    evs.append(explained_variance_score(y_true=y_test, y_pred=y_pred))
    r_squared_score.append(r2_score(y_true=y_test, y_pred=y_pred))
# Out:
# [ 609894.63901094  916531.25153437  663471.75121297 ... -207158.85462366
#  1611489.48287063  745805.75179814]
# [ 609890.22618588  916541.85184823  663502.55384051 ... -207166.78217411
#  1611508.5897595   745831.31846713]
# [ 609892.87964943  916531.68543056  663474.54866316 ... -207155.59280742
#  1611490.43050034  745805.31186769]
# [554368.1687832  555229.02331957 555035.85891764 ... 553950.53991914
#  555714.87312364 555032.10836973]
# [ 550000.  815000.  749000. ...  199000. 1700000.  800000.]
# [ 540930.          829760.          673940.         ...  178890.
#  1700567.85714286  721490.        ]

# %%
ml_models_df = pd.DataFrame({
    'Models': ['LinearRegression', 'Ridge', 'Lasso', 'SVR', 'DecisionTreeRegressor', 'RandomForestRegressor'],
    'mean_absolute_error':mae,
    'mean_squared_error':mse,
    'root_mean_squared_error':rmse,
    'explained_variance_score':evs,
    'r2_score':r_squared_score    
    
})

ml_models_df.set_index('Models', inplace=True)

ml_models_df
# Out:
#                        mean_absolute_error  mean_squared_error  \
# Models
# LinearRegression             270609.044982        2.316335e+11
# Ridge                        270592.910069        2.316328e+11
# Lasso                        270608.406386        2.316335e+11
# SVR                          410828.311381        7.981323e+11
# DecisionTreeRegressor        132890.658450        2.859172e+11
# RandomForestRegressor        105440.676563        5.213767e+10
#
#                        root_mean_squared_error  explained_variance_score  \
# Models
# LinearRegression                 481283.201357                  0.688639
# Ridge                            481282.444606                  0.688640
# Lasso                            481283.153854                  0.688639
# SVR                              893382.492125                  0.000843
# DecisionTreeRegressor            534712.297630                  0.615797
# RandomForestRegressor            228336.738808                  0.929942
#
#                        r2_score
# Models
# LinearRegression       0.688638
# Ridge                  0.688639
# Lasso                  0.688638
# SVR                   -0.072850
# DecisionTreeRegressor  0.615670
# RandomForestRegressor  0.929916

# %% [markdown]
# # HyperParameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
# define tune params

params_grid ={
    LinearRegression:{},
    SVR:{
        'kernel':['rbf', 'linear'],
        'C':[0.1,1,10],
        'epsilon':[0.01,0.1,0.5]
    },
    DecisionTreeRegressor:{
        'max_depth':[None, 5,10,20],
        'min_samples_split':[2,5,10]
    },
    RandomForestRegressor:{
        'n_estimators':[50,100],
        'max_depth':[None, 5,10,20],
        'min_samples_split':[2,5,10]
    },
    Ridge:{
        'alpha':[0.1,1.0,10.0]

    },
    Lasso:{
        
        'alpha':[0.001,0.1,1.0]
    }
}

models = [LinearRegression, Ridge, Lasso, SVR, DecisionTreeRegressor, RandomForestRegressor]

mae=[]
mse=[]
rmse =[]
evs = []
r_squared_score = []
best_models =[]

for model in models:

    print(f'Tuning:{model.__name__}')

    if params_grid[model]:
        grid= GridSearchCV(model(), param_grid=params_grid[model], cv=5,scoring='r2', n_jobs=-1)
        grid.fit(X_train_scaled, y_train)
        regressor = grid.best_estimator_
        print("Best Parameters:", grid.best_params_)
    else:
        regressor= model().fit(X_train_scaled, y_train)
    
    y_pred = regressor.predict(X_test_scaled)

    mae.append(mean_absolute_error(y_true=y_test, y_pred=y_pred))
    mse.append(mean_squared_error(y_true=y_test, y_pred=y_pred))
    rmse.append(np.sqrt(mean_squared_error(y_true=y_test, y_pred=y_pred)))
    evs.append(explained_variance_score(y_true=y_test, y_pred=y_pred))
    r_squared_score.append(r2_score(y_true=y_test, y_pred=y_pred))
    best_models.append(regressor)
# Out:
# Tuning:LinearRegression
# Tuning:Ridge
# Best Parameters: {'alpha': 10.0}
# Tuning:Lasso
# /Users/akshay/Desktop/CarPricePrediction/carPriceVenv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.527e+14, tolerance: 8.372e+11
#   model = cd_fast.enet_coordinate_descent(
# /Users/akshay/Desktop/CarPricePrediction/carPriceVenv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.484e+14, tolerance: 8.316e+11
#   model = cd_fast.enet_coordinate_descent(
# /Users/akshay/Desktop/CarPricePrediction/carPriceVenv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.681e+14, tolerance: 8.672e+11
#   model = cd_fast.enet_coordinate_descent(
# /Users/akshay/Desktop/CarPricePrediction/carPriceVenv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.681e+14, tolerance: 8.672e+11
#   model = cd_fast.enet_coordinate_descent(
# /Users/akshay/Desktop/CarPricePrediction/carPriceVenv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.484e+14, tolerance: 8.316e+11
#   model = cd_fast.enet_coordinate_descent(
# /Users/akshay/Desktop/CarPricePrediction/carPriceVenv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.527e+14, tolerance: 8.372e+11
#   model = cd_fast.enet_coordinate_descent(
# Best Parameters: {'alpha': 1.0}
# Tuning:SVR
# Best Parameters: {'C': 10, 'epsilon': 0.01, 'kernel': 'linear'}
# Tuning:DecisionTreeRegressor
# Best Parameters: {'max_depth': 10, 'min_samples_split': 2}
# Tuning:RandomForestRegressor
# Best Parameters: {'max_depth': None, 'min_samples_split': 5, 'n_estimators': 50}

# %%
ml_models_df = pd.DataFrame({
    'Models': ['LinearRegression','Ridge', 'Lasso', 'SVR', 'DecisionTreeRegressor', 'RandomForestRegressor'],
    'mean_absolute_error': mae,
    'mean_squared_error': mse,
    'root_mean_squared_error': rmse,
    'explained_variance_score': evs,
    'r2_score': r_squared_score
})

ml_models_df.set_index('Models', inplace=True)

ml_models_df
# Out:
#                        mean_absolute_error  mean_squared_error  \
# Models
# LinearRegression             270609.044982        2.316335e+11
# Ridge                        270448.550858        2.316272e+11
# Lasso                        270608.406386        2.316335e+11
# SVR                          309836.020196        5.852022e+11
# DecisionTreeRegressor        127367.865594        1.201988e+11
# RandomForestRegressor        106302.959483        5.678393e+10
#
#                        root_mean_squared_error  explained_variance_score  \
# Models
# LinearRegression                 481283.201357                  0.688639
# Ridge                            481276.584358                  0.688647
# Lasso                            481283.153854                  0.688639
# SVR                              764985.114997                  0.263378
# DecisionTreeRegressor            346696.960639                  0.838468
# RandomForestRegressor            238293.797697                  0.923707
#
#                        r2_score
# Models
# LinearRegression       0.688638
# Ridge                  0.688647
# Lasso                  0.688638
# SVR                    0.213370
# DecisionTreeRegressor  0.838429
# RandomForestRegressor  0.923671

# %%
best_models
# Out:
# [LinearRegression(),
#  Ridge(alpha=10.0),
#  Lasso(),
#  SVR(C=10, epsilon=0.01, kernel='linear'),
#  DecisionTreeRegressor(max_depth=10),
#  RandomForestRegressor(min_samples_split=5, n_estimators=50)]

# %% [markdown]
# # Genrating Pickle File - Save the trained Model

# %%
import pickle

models =[LinearRegression(),
 Ridge(alpha=10.0),
 Lasso(),
 SVR(C=10, epsilon=0.01, kernel='linear'),
 DecisionTreeRegressor(max_depth=10),
 RandomForestRegressor(min_samples_split=5, n_estimators=50)]

model_save_path = './saved_models/'
os.makedirs(model_save_path, exist_ok=True)

for model in models:
    model_name = type(model).__name__
    model.fit(X_train_scaled, y_train)
    filename = f'{model_name}.pkl'
    print(f"Saving :{filename}")
          
    model_path = os.path.join(model_save_path, filename)
    with open(model_path, 'wb') as f:
        pickle.dump(model, f)
        
    print(f"Trainned and Saved :{filename} model successfully")
# Out:
# Saving :LinearRegression.pkl
# Trainned and Saved :LinearRegression.pkl model successfully
# Saving :Ridge.pkl
# Trainned and Saved :Ridge.pkl model successfully
# Saving :Lasso.pkl
# Trainned and Saved :Lasso.pkl model successfully
# Saving :SVR.pkl
# Trainned and Saved :SVR.pkl model successfully
# Saving :DecisionTreeRegressor.pkl
# Trainned and Saved :DecisionTreeRegressor.pkl model successfully
# Saving :RandomForestRegressor.pkl
# Trainned and Saved :RandomForestRegressor.pkl model successfully

# %% [markdown]
# # Saving scaled trained data

# %%
os.makedirs('./saved_scaling/', exist_ok=True)

with open('./saved_scaling/scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)

# %% [markdown]
# # loading the model

# %%
model_path = './saved_models/RandomForestRegressor.pkl'

with open(model_path, 'rb') as f:
    random_forest_model = pickle.load(f)

# %%
random_forest_model
# Out:
# RandomForestRegressor(min_samples_split=5, n_estimators=50)

# %%
random_forest_model.score(X_train_scaled,y_train)
# Out:
# 0.9629989605296816

# %%
random_forest_model.score(X_test_scaled,y_test)
# Out:
# 0.9184147501790557
